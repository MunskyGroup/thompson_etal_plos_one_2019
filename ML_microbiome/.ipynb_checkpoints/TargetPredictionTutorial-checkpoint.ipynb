# %% [markdown]
# # Run Random Forest and Neural Network Prediction Model with Hyper-Parameter Tuning

# %% [markdown]
# First, import the RFINN package

# %%
from RFINN import *

# %% [markdown]
# Data must be uploaded as Pandas DataFrames with each sample in rows and each feature in columns. The data file with targets is slightly different, with sample IDs as columns.
#
# This is accomplished by first importing the Pandas library:

# %%
import pandas as pd

# %% [markdown]
# Upload DataFrames of training, testing, and target data using pd.read_csv()

# %%
# import training and test data as pandas dataframes
train_data = pd.read_csv('train_data.csv')
test_data = pd.read_csv('test_data.csv')
targets = pd.read_csv('DOC_targets.csv')

# %% [markdown]
# Let's start by setting up a Random Forest Regression model:

# %%
# instantiate model class
model = Model('Random Forest', train_data, test_data, targets)

# %% [markdown]
# Training and Testing the model followed by hyper-parameter optimization is accomplished with the following commands:

# %%
# optimize hyper-parameters 
print(model.tune_hyper_params())

# train model
model.train_model()

# test model
Y_test, Y_pred_test, R = model.test_model()
# Out:
# {'min_samples_split': 2, 'min_samples_leaf': 2}

# %%
# print prediction performance results 
print("Pearson's R: {:.3f}".format(R))
MSE = sum((Y_test - Y_pred_test)**2) / len(Y_test)
print("Mean Squared Error: {:.3f}".format(MSE))
# Out:
# Pearson's R: 0.684
# Mean Squared Error: 0.505

# %% [markdown]
# Implementing a Neural Network model requires specifying 'Neural Network' when instantiating the model:

# %%
# instantiate model class as Neural Network
model = Model('Neural Network', train_data, test_data, targets)

# %% [markdown]
# Training and Testing the model is the same as before:

# %%
# tune hyper parameters for model
# print(model.tune_hyper_params())

# train model
model.train_model()

# test model
Y_test, Y_pred_test, R = model.test_model()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-735c80be56bd> in <module>()
#       1 # tune hyper parameters for model
# ----> 2 print(model.tune_hyper_params())
#       3
#       4 # train model
#       5 model.train_model()
#
# ~/Documents/Thesis/thompson_etal_plos_one_2019/ML_microbiome/RFINN/ML_microbiome.py in tune_hyper_params(self)
#     116         # tune hyper parameters using Scikit Learn's random search algorithm
#     117         # print("Tuning hyper-parameters...")
# --> 118         return self.model.tune(self.X_train, self.Y_train)
#     119
#     120     def train_model(self):
#
# ~/Documents/Thesis/thompson_etal_plos_one_2019/ML_microbiome/RFINN/ML_microbiome.py in tune(self, X_train, Y_train)
#     357         # load train and test features as numpy arrays
#     358         self.Model_Class = Model_Class
# --> 359         self.NF = NF
#     360         self.net = Network(NF)
#     361
#
# ~/anaconda3/lib/python3.5/site-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     637                                   error_score=self.error_score)
#     638           for parameters, (train, test) in product(candidate_params,
# --> 639                                                    cv.split(X, y, groups)))
#     640
#     641         # if one choose to see train score, "out" will contain train score info
#
# ~/anaconda3/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py in __call__(self, iterable)
#     787                 # consumption.
#     788                 self._iterating = False
# --> 789             self.retrieve()
#     790             # Make sure that we get a last message telling us we are done
#     791             elapsed_time = time.time() - self._start_time
#
# ~/anaconda3/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py in retrieve(self)
#     697             try:
#     698                 if getattr(self._backend, 'supports_timeout', False):
# --> 699                     self._output.extend(job.get(timeout=self.timeout))
#     700                 else:
#     701                     self._output.extend(job.get())
#
# ~/anaconda3/lib/python3.5/multiprocessing/pool.py in get(self, timeout)
#     636
#     637     def get(self, timeout=None):
# --> 638         self.wait(timeout)
#     639         if not self.ready():
#     640             raise TimeoutError
#
# ~/anaconda3/lib/python3.5/multiprocessing/pool.py in wait(self, timeout)
#     633
#     634     def wait(self, timeout=None):
# --> 635         self._event.wait(timeout)
#     636
#     637     def get(self, timeout=None):
#
# ~/anaconda3/lib/python3.5/threading.py in wait(self, timeout)
#     547             signaled = self._flag
#     548             if not signaled:
# --> 549                 signaled = self._cond.wait(timeout)
#     550             return signaled
#     551
#
# ~/anaconda3/lib/python3.5/threading.py in wait(self, timeout)
#     291         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     292             if timeout is None:
# --> 293                 waiter.acquire()
#     294                 gotit = True
#     295             else:
#
# KeyboardInterrupt:

# %%
# print prediction performance results 
print("Pearson's R: {:.3f}".format(R))
MSE = sum((Y_test - Y_pred_test)**2) / len(Y_test)
print("Mean Squared Error: {:.3f}".format(MSE))
